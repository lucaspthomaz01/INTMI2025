# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaspthomaz01/INTMI2025/blob/main/ALP_LUCAS_PORTA_TOMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ALgoritmo e lógica de programação

# %% [markdown]
# ##Variáveis e Operadores

# %%
x = 5         #Isso é uma variavél
print(x)
# Out:
# 5

# %% [markdown]
# ##Operadores
#
# adição +
#
# subtração -
#
# Divisão /
#
# Multplicação *
#
# Resto da Divisão %
#
# Divisão Inteira //
#
# Exponenciação **

# %%
numero1 = 10
numero2 = 5

print(" A soma é igual a: " , numero1 + numero2)
print(" A subtração é igual a: " , numero1 - numero2)
print(" A divisão é igual a: " , numero1 / numero2)
print(" A multiplicação é igual a: " , numero1 * numero2)
print(" A resto é igual a: " , numero1 % numero2)
print(" A divisão inteira é igual a: " , numero1 // numero2)
print(" A exponenciação é igual a: " , numero1 ** numero2)
# Out:
#  A soma é igual a:  15
#  A subtração é igual a:  5
#  A divisão é igual a:  2.0
#  A multiplicação é igual a:  50
#  A resto é igual a:  0
#  A divisão inteira é igual a:  2
#  A exponenciação é igual a:  100000

# %%
idade = input ("Digite a sua idade:")
# Out:
# Digite a sua idade:16

# %% [markdown]
# ##Tipos de dados
#
# int - para números inteiros (1 , 2, 3 )
#
# str - para palavras e texto (palavra)
#
# float - para números com vírgula (1.5 , 2.3 )
#
# bool - para binários, verdadeiro ou falso (True, False)

# %%
altura = float(input("DIgite sua altura: "))
peso = float(input("Digite seu peso: "))

imc = peso / (altura * altura)
print("Seu IMC é: " , imc)
# Out:
# DIgite sua altura: 1.8
# Digite seu peso: 50
# Seu IMC é:  15.432098765432098

# %% [markdown]
# ##ESTRUTURA CONDICIONAL
#
# if - se
#
# elif - senão se
#
# else - senão

# %%
nota = float(input("Digite a sua nota: "))

if (nota >= 7):
  print("Aprovado")
elif (nota >= 5):
  print("Recuperação")
else:
  print("Reprovado")
# Out:
# Digite a sua nota: 1000
# Aprovado

# %% [markdown]
# 4 - Crie um algoritmo que leia a sua idade e dependendo da idade mostre as frases na tela:
#
# até 12 anos-Você é uma Criança!
#
# 13-18-Você é Adolescente!
#
# 19-60-Você é Adulto!
#
# acima de 60-Você é idoso!

# %%
idade = int(input("Digite a sua idade:"))

if (idade <= 12):
  print("Você é uma criança!")
elif (idade <= 18):
  print("Você é um adolescente!")
elif (idade <= 60):
  print("Você é um adulto!")
else:
  print("Você é um idoso!")
# Out:
# Digite a sua idade:16
# Você é um adolescente!

# %% [markdown]
# 5 - Crie um algoritmo que receba 2 numeros e uma escolha que mostre o seguinte menu:
#
# Selecione o sinal:
#
# 1 - Adição
#
# 2 - Subtração
#
# 3 - Multiplicação
#
# 4 - Divisão
#
# caso não escolha um numeros válido apareça na tela: Opção inválida!
#
# se escolher 1 some os 2 números e mostre o resultado.
#
# se escolher 2 subtraia os 2 números e mostre o resultado.
#
# e assim com as outras opções.
